# %% [markdown]
# ## Сбор данных

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# Работа посвещана созданию рекомендательной системы фильмов для онлайн кинотеатров. Для этого потребуются соответствующие данные о фильмах и их рейтингах.
#
# Загружаем мета-данные фильмов [с kaggle](https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset/data). Набор данных состоит из более 45000 фильмов, выпущенных до июля 2017 года.

# %% [markdown]
# #### Содержание файлов:
#
# - <b>Movies_metadata.csv</b>: основной файл метаданных фильмов. Содержит информацию о 45 000 фильмах, представленных в наборе данных Full MovieLens. Характеристики включают posters, backdrops, budget, revenue, release dates, languages, production countries и companies.
# - <b>keywords.csv</b>: содержит ключевые слова сюжета (movie plot keywords) для наших фильмов MovieLens. Доступен в виде строкового объекта JSON.
# - <b>credits.csv</b>: Содержит информацию об актерах и съемочной группе (Cast and Crew) всех наших фильмов. Доступен в виде строкового объекта JSON.
# - <b>links.csv</b>: файл, содержащий TMDB и идентификаторы IMDB всех фильмов, представленных в наборе данных Full MovieLens.
# - <b>link_small.csv</b>: содержит TMDB и идентификаторы IMDB небольшого подмножества из 9000 фильмов полного набора данных.
# - <b>ratings_small.csv</b>: Подмножество из 100 000 оценок 700 пользователей к 9 000 фильмам.

# %%
old_keywords = pd.read_csv('data/keywords.csv')
old_links = pd.read_csv('data/links.csv')
old_retings = pd.read_csv('data/ratings.csv')
old_credits = pd.read_csv("data/credits.csv")
movies_metadata = pd.read_csv("data/movies_metadata.csv")

movies_metadata.head(3)
# Out:
# C:\Users\Valeriia\AppData\Local\Temp\ipykernel_84388\1521140142.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_metadata = pd.read_csv("data/movies_metadata.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 2  Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
# 2   1995-12-22          0.0   101.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 0          7.7     5415.0
# 1          6.9     2413.0
# 2          6.5       92.0
#
# [3 rows x 24 columns]

# %% [markdown]
# Данные достаточно старые, поэтому я решила скачать полный набор [MovieLens](https://grouplens.org/datasets/movielens/latest/)
#
# Согласно приложенному файлу описания датасета, он был создан 20 июля 2023 г., поэтому должен содержать информацию о новых фильмах, выпущенных к этому времени.
#
#
# #### Содержание файлов:
#
# - <b>«genome-tags.csv»</b> и <b>«genome-scores.csv»</b> - геном тега. Геном тега кодирует, насколько сильно фильмы демонстрируют определенные свойства, представленные тегами. Геном тега был рассчитан с использованием алгоритма машинного обучения на основе пользовательского контента, включая теги, рейтинги и текстовые обзоры. Геном разделен на два файла. Файл <b>genome-scores.csv</b> содержит данные о релевантности тегов фильмов в следующем формате:  movieId,tagId,relevance. Второй файл, <b>genome-tags.csv</b>, содержит описания тегов для идентификаторов тегов в файле генома в следующем формате: tagId,tag.
# - <b>«links.csv»</b> - идентификаторы, которые можно использовать для ссылки на другие источники данных фильма. Каждая строка этого файла после строки заголовка представляет один фильм и имеет следующий формат: movieId, imdbId, tmdbId
# - <b>«movies.csv»</b> - фильмы. Каждая строка этого файла после строки заголовка представляет один фильм и имеет следующий формат: movieId, title, genres
# - <b>«ratings.csv»</b> - рейтинги. Каждая строка этого файла после строки заголовка представляет одну оценку одного фильма одним пользователем и имеет следующий формат: userId, movieId, rating, timestamp
# - <b>«tags.csv»</b> - теги. Каждая строка этого файла после строки заголовка представляет собой один тег, примененный к одному фильму одним пользователем, и имеет следующий формат: userId, movieId, tag, timestamp.Теги — это метаданные о фильмах, созданные пользователем. Каждый тег обычно представляет собой одно слово или короткую фразу. Смысл, значение и назначение конкретного тега определяет каждый пользователь.

# %%
movies = pd.read_csv('full_data/movies.csv')
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
links = pd.read_csv('full_data/links.csv')
links.head(3)
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0

# %%
movies.shape, links.shape
# Out:
# ((86537, 3), (86537, 3))

# %% [markdown]
# В полном наборе содержаться более 86 тысяч записей. Следовательно в период с 2017 - 2023 было выпущено более 20000 фильмов.

# %%
movies.loc[~movies.movieId.isin(links.movieId)]
# Out:
# Empty DataFrame
# Columns: [movieId, title, genres]
# Index: []

# %% [markdown]
# Индикаторы в файлах links и movies полностью совпадают. Но для создания рекомендательной системы мне нужны метаданные, ключевые слова и информация о съемочной группы и актерах, которые отсутствуют у новых фильмов. Решением данного вопроса стал сбор данных с помощью api, предоставленный api.themoviedb.org.
#
# Для сбора данных потребуется индикатор tmdbId.

# %%
links.isna().sum()
# Out:
# movieId      0
# imdbId       0
# tmdbId     126
# dtype: int64

# %% [markdown]
# У 126 записей отсутствует индикатор tmdbId. На api.themoviedb.org есть возможность поиска tmdbId через imdbId, чем я и воспользуюсь. Для того, чтобы использовать его, требуется получить API key. Инструкцию как это сделать можно найти на [сайте](https://developer.themoviedb.org/docs).
#
# Так как я уже получила свой ключ, я импортирую его в ноутбук.

# %%
import configparser
config = configparser.ConfigParser()
config.read("config.ini", encoding='utf-8')

token = config["API"]["token"]
api_key = config["API"]["api_key"]

# %%
def get_tmdbId(imdbId):
    a = 7 - len(str(imdbId))
    if a > 0:
        imdb_id = 'tt' + '0'*a + str(imdbId)
    else:
        imdb_id = 'tt' + str(imdbId)
    url = f"https://api.themoviedb.org/3/find/{imdb_id}?external_source=imdb_id"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }

    response = requests.get(url, headers=headers)
    if not response.ok:
        print(response.text)
        return np.nan
    if not response.json()['movie_results']:
        return np.nan    
    tmdbId = response.json()['movie_results'][0]['id']
    return tmdbId

# %%
imdbId_list = links.loc[links.tmdbId.isna(), 'imdbId']

# %%
tmdbId_list = imdbId_list.map(get_tmdbId)

# %%
links.loc[links.tmdbId.isna(), 'tmdbId'] = tmdbId_list

# %%
links.isna().sum()
# Out:
# movieId     0
# imdbId      0
# tmdbId     58
# dtype: int64

# %% [markdown]
# Не получилось собрать все tmdbId, но так как отсутствие 58 записей никак не скажется на построении рекамендательной системы, то я удалю пропуски и поменяю формат данных колонки tmdbId на целочисленный.

# %%
links = links.drop(links[links.tmdbId.isna()].index)

# %%
links.tmdbId = links.tmdbId.astype('int')

# %%
links.to_csv('full_data/links.csv', index=False)

# %% [markdown]
# Сначала проверим работоспособность и полученные данные запроса метаданных фильма "Toy Story", который уже у нас есть.

# %%
tmdbId = 862
url = f"https://api.themoviedb.org/3/movie/{tmdbId}?append_to_response=production_companies&language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": token
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'adult': False,
#  'backdrop_path': '/lxD5ak7BOoinRNehOCA85CQ8ubr.jpg',
#  'belongs_to_collection': {'id': 10194,
#   'name': 'Toy Story Collection',
#   'poster_path': '/rki5qLuwb0xnnE9seehxO9TlLhW.jpg',
#   'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'},
#  'budget': 30000000,
#  'genres': [{'id': 16, 'name': 'Animation'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 35, 'name': 'Comedy'}],
#  'homepage': 'http://toystory.disney.com/toy-story',
#  'id': 862,
#  'imdb_id': 'tt0114709',
#  'original_language': 'en',
#  'original_title': 'Toy Story',
#  'overview': "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.",
#  'popularity': 115.249,
#  'poster_path': '/uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg',
#  'production_companies': [{'id': 3,
#    'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png',
#    'name': 'Pixar',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1995-10-30',
#  'revenue': 394400000,
#  'runtime': 81,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Hang on for the comedy that goes to infinity and beyond!',
#  'title': 'Toy Story',
#  'video': False,
#  'vote_average': 7.97,
#  'vote_count': 17320}

# %%
movies_metadata.loc[movies_metadata.id == '862'][['title', 'vote_average', 'vote_count', 'popularity', 'genres']].T
# Out:
#                                                               0
# title                                                 Toy Story
# vote_average                                                7.7
# vote_count                                               5415.0
# popularity                                            21.946943
# genres        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...

# %% [markdown]
# Те данные, которые у нас есть, и те, которые мы получили, не совпадают. Это не удивительно, так как с прошествием 6 лет этот фильм могло просмотреть большее количество людей, в следствии чего количество голосов, средняя оценка и значение популярности может поменяться. Так же были небольшие корректировки в жанре.
#
# Делаем вывод, что метаданные подвержены изменениям с течением времени и их нужно обновить.
#
# Что касается информации о ключевых словах и информации об актерах и съемочной группе, то маловероятно, что такая информация будет изменена. Поэтому мы возьмем те данные, которые уже есть.

# %% [markdown]
# Создаем датафреймы, в который будем вносить данные:

# %%
movies = pd.DataFrame({'tmdbId': links.tmdbId.tolist()})

# %%
detail_keys = response.json().keys()

# %%
for d_key in detail_keys:
    movies.insert(movies.shape[1], d_key, np.nan)
movies.head(2)
# Out:
#    tmdbId  adult  backdrop_path  belongs_to_collection  budget  genres  \
# 0     862    NaN            NaN                    NaN     NaN     NaN
# 1    8844    NaN            NaN                    NaN     NaN     NaN
#
#    homepage  id  imdb_id  original_language  ...  release_date  revenue  \
# 0       NaN NaN      NaN                NaN  ...           NaN      NaN
# 1       NaN NaN      NaN                NaN  ...           NaN      NaN
#
#    runtime  spoken_languages  status  tagline  title  video  vote_average  \
# 0      NaN               NaN     NaN      NaN    NaN    NaN           NaN
# 1      NaN               NaN     NaN      NaN    NaN    NaN           NaN
#
#    vote_count
# 0         NaN
# 1         NaN
#
# [2 rows x 26 columns]

# %% [markdown]
# Заполняем credits и keywords данными:

# %%
credits = pd.DataFrame({'tmdbId': links.tmdbId.tolist()})
keywords = pd.DataFrame({'tmdbId': links.tmdbId.tolist()})

old_keywords.rename(columns={'id': 'tmdbId'}, inplace=True)
keywords = keywords.merge(old_keywords, on='tmdbId', how='left')

old_credits.rename(columns={'id': 'tmdbId'}, inplace=True)
credits = credits.merge(old_credits, on='tmdbId', how='left')

credits_keys = ['cast', 'crew']
keywords_key = ['keywords']

# %%
import time
import datetime

def get_info(tmdbId):
    try:
        headers = {
            "accept": "application/json",
            "Authorization": token
            }
        
        # get details
        # часто нет tagline и homepage, поэтому общая сумма пропусков по колонкам не должна превышать 2 
        if movies.loc[movies.tmdbId == tmdbId].isna().sum().sum() > 2:
            url = f"https://api.themoviedb.org/3/movie/{tmdbId}??api_key={api_key}&append_to_response=production_companies&language=en-US"

            response = requests.get(url, headers=headers)
            if not response.ok:
                print(f'{datetime.datetime.now().strftime("%H:%M:%S")} -  Не получили details данные {tmdbId}')
                # сохраняем индификаторы записей, которые не нашли, чтобы в случае повторного запуска кода,
                # не проходить по ним заново
                with open('error_requests.txt', 'a') as f:
                    f.write(str(tmdbId) + '\n')
                    print("/tСохранен в error_requests.txt ")
            else:
                details = dict(response.json())
                for d_key in detail_keys:
                    if d_key in details.keys():
                        movies.loc[movies.tmdbId == tmdbId, d_key] = str(details[d_key])

        # get keywords
        # было замечено, что в датасете вместо nan записан [], который приравнивается к пропуску.
        if keywords.loc[keywords.tmdbId == tmdbId].isna().sum().sum() > 0 or keywords.loc[keywords.tmdbId == tmdbId, 'keywords'].values[0] == '[]':
            url = f"https://api.themoviedb.org/3/movie/{tmdbId}/keywords?api_key={api_key}"
            response = requests.get(url, headers=headers)
            if not response.ok:
                print(f'{ datetime.datetime.now().strftime("%H:%M:%S")} - Не получили keywords данные {tmdbId}')
            else:
                keywords_set = dict(response.json())
                for k_key in keywords_key:
                    if k_key in keywords_set.keys():
                        keywords.loc[keywords.tmdbId == tmdbId, k_key] = str(keywords_set[k_key])

        # get credits
        if credits.loc[credits.tmdbId == tmdbId].isna().sum().sum() > 0 or credits.loc[credits.tmdbId == tmdbId, 'cast'].values[0] == '[]' or credits.loc[credits.tmdbId == tmdbId, 'crew'].values[0] == '[]':
            url = f"https://api.themoviedb.org/3/movie/{tmdbId}/credits?api_key={api_key}&language=en-US"
            response = requests.get(url, headers=headers)
            if not response.ok:
                print(f'{ datetime.datetime.now().strftime("%H:%M:%S")} - Не получили credits данные {tmdbId}')
            else:
                credits_set = dict(response.json())
                for c_key in credits_keys:
                    if c_key in credits_set.keys():
                        credits.loc[credits.tmdbId == tmdbId, c_key] = str(credits_set[c_key])
        
        # save files
        if tmdbId%5 == 0:
            movies.to_csv('full_data/movie_metadata.csv', index=False)
            keywords.to_csv('full_data/keywords.csv', index=False)
            credits.to_csv('full_data/credits.csv', index=False)
            print(f'{ datetime.datetime.now().strftime("%H:%M:%S")} - Сохранение датасетов. Сейчас есть {movies.adult.isna().sum()} пропусков')
            
    except Exception as e:
        print(e)
        time.sleep(120)
        print(f'Sleep at {tmdbId}')

# %%
tmdbIds = movies.loc[(movies.adult.isna()) & (~movies.tmdbId.isin(error_tmdbIds)), 'tmdbId']

# %%
tmdbIds = tmdbIds.drop_duplicates()

# %% [markdown]
# Запускаем функцию сбора данных

# %%
tmdbIds.map(get_info)
# Out:
# 19:53:35 -  Не получили details данные 538286
# /tСохранен в error_requests.txt
# 19:53:37 - Не получили keywords данные 538286
# 19:53:38 - Не получили credits данные 538286
# 19:53:39 -  Не получили details данные 12773
# /tСохранен в error_requests.txt
# 19:53:41 - Не получили keywords данные 12773
# 19:53:43 - Не получили credits данные 12773
# 19:53:44 -  Не получили details данные 17882
# /tСохранен в error_requests.txt
# 19:53:46 - Не получили keywords данные 17882
# 19:53:48 - Не получили credits данные 17882
# 19:53:49 -  Не получили details данные 68149
# /tСохранен в error_requests.txt
# 19:53:50 - Не получили keywords данные 68149
# 19:53:51 - Не получили credits данные 68149
# 19:53:53 -  Не получили details данные 14980
# /tСохранен в error_requests.txt
# 19:54:10 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:54:11 -  Не получили details данные 164721
# /tСохранен в error_requests.txt
# 19:54:13 - Не получили keywords данные 164721
# 19:54:14 - Не получили credits данные 164721
# 19:54:15 -  Не получили details данные 2413
# /tСохранен в error_requests.txt
# 19:54:17 - Не получили keywords данные 2413
# 19:54:19 - Не получили credits данные 2413
# 19:54:21 -  Не получили details данные 37452
# /tСохранен в error_requests.txt
# 19:54:23 - Не получили keywords данные 37452
# 19:54:25 - Не получили credits данные 37452
# 19:54:27 -  Не получили details данные 47350
# /tСохранен в error_requests.txt
# 19:54:45 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:54:46 -  Не получили details данные 11944
# /tСохранен в error_requests.txt
# 19:54:47 -  Не получили details данные 26491
# /tСохранен в error_requests.txt
# 19:54:49 -  Не получили details данные 2518
# /tСохранен в error_requests.txt
# 19:54:50 - Не получили keywords данные 2518
# 19:54:52 - Не получили credits данные 2518
# 19:54:53 -  Не получили details данные 36763
# /tСохранен в error_requests.txt
# 19:54:55 -  Не получили details данные 64699
# /tСохранен в error_requests.txt
# 19:54:57 - Не получили keywords данные 64699
# 19:54:59 - Не получили credits данные 64699
# 19:55:01 -  Не получили details данные 69234
# /tСохранен в error_requests.txt
# 19:55:03 -  Не получили details данные 13716
# /tСохранен в error_requests.txt
# 19:55:04 - Не получили keywords данные 13716
# 19:55:05 - Не получили credits данные 13716
# 19:55:06 -  Не получили details данные 11343
# /tСохранен в error_requests.txt
# 19:55:08 -  Не получили details данные 185441
# /tСохранен в error_requests.txt
# 19:55:10 - Не получили keywords данные 185441
# 19:55:11 - Не получили credits данные 185441
# 19:55:13 -  Не получили details данные 10700
# /tСохранен в error_requests.txt
# 19:55:15 - Не получили keywords данные 10700
# 19:55:16 - Не получили credits данные 10700
# 19:55:29 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:55:30 -  Не получили details данные 37525
# /tСохранен в error_requests.txt
# 19:55:32 - Не получили keywords данные 37525
# 19:55:33 - Не получили credits данные 37525
# 19:55:46 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:55:48 -  Не получили details данные 24269
# /tСохранен в error_requests.txt
# 19:55:50 -  Не получили details данные 41758
# /tСохранен в error_requests.txt
# 19:55:52 - Не получили keywords данные 41758
# 19:55:54 -  Не получили details данные 58923
# /tСохранен в error_requests.txt
# 19:55:55 - Не получили keywords данные 58923
# 19:55:57 -  Не получили details данные 17919
# /tСохранен в error_requests.txt
# 19:55:59 -  Не получили details данные 78057
# /tСохранен в error_requests.txt
# 19:56:00 - Не получили keywords данные 78057
# 19:56:01 - Не получили credits данные 78057
# 19:56:03 -  Не получили details данные 27138
# /tСохранен в error_requests.txt
# 19:56:05 -  Не получили details данные 49870
# /tСохранен в error_requests.txt
# 19:56:06 - Не получили keywords данные 49870
# 19:56:19 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:56:20 -  Не получили details данные 244797
# /tСохранен в error_requests.txt
# 19:56:22 - Не получили keywords данные 244797
# 19:56:23 - Не получили credits данные 244797
# 19:56:24 -  Не получили details данные 53094
# /tСохранен в error_requests.txt
# 19:56:26 -  Не получили details данные 31653
# /tСохранен в error_requests.txt
# 19:56:27 - Не получили keywords данные 31653
# 19:56:28 - Не получили credits данные 31653
# 19:56:29 -  Не получили details данные 118309
# /tСохранен в error_requests.txt
# 19:56:30 - Не получили keywords данные 118309
# 19:56:31 -  Не получили details данные 17800
# /tСохранен в error_requests.txt
# 19:56:33 - Не получили keywords данные 17800
# 19:56:34 - Не получили credits данные 17800
# 19:56:47 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:56:48 -  Не получили details данные 12224
# /tСохранен в error_requests.txt
# 19:56:49 -  Не получили details данные 9795
# /tСохранен в error_requests.txt
# 19:57:01 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:57:03 -  Не получили details данные 18884
# /tСохранен в error_requests.txt
# 19:57:04 -  Не получили details данные 14301
# /tСохранен в error_requests.txt
# 19:57:05 -  Не получили details данные 38870
# /tСохранен в error_requests.txt
# 19:57:06 - Не получили keywords данные 38870
# 19:57:07 - Не получили credits данные 38870
# 19:57:20 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:57:21 -  Не получили details данные 168643
# /tСохранен в error_requests.txt
# 19:57:22 -  Не получили details данные 45560
# /tСохранен в error_requests.txt
# 19:57:23 - Не получили keywords данные 45560
# 19:57:36 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:57:37 -  Не получили details данные 62128
# /tСохранен в error_requests.txt
# 19:57:38 -  Не получили details данные 67479
# /tСохранен в error_requests.txt
# 19:57:39 - Не получили keywords данные 67479
# 19:57:40 - Не получили credits данные 67479
# 19:57:41 -  Не получили details данные 67463
# /tСохранен в error_requests.txt
# 19:57:43 -  Не получили details данные 200039
# /tСохранен в error_requests.txt
# 19:57:44 - Не получили keywords данные 200039
# 19:57:45 - Не получили credits данные 200039
# 19:57:46 -  Не получили details данные 65990
# /tСохранен в error_requests.txt
# 19:57:58 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:58:02 -  Не получили details данные 113879
# /tСохранен в error_requests.txt
# 19:58:03 - Не получили keywords данные 113879
# 19:58:04 - Не получили credits данные 113879
# 19:58:06 -  Не получили details данные 25950
# /tСохранен в error_requests.txt
# 19:58:08 - Не получили keywords данные 25950
# 19:58:20 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:58:21 -  Не получили details данные 141714
# /tСохранен в error_requests.txt
# 19:58:22 -  Не получили details данные 61917
# /tСохранен в error_requests.txt
# 19:58:24 - Не получили keywords данные 61917
# 19:58:26 - Не получили credits данные 61917
# 19:58:28 -  Не получили details данные 61919
# /tСохранен в error_requests.txt
# 19:58:29 - Не получили keywords данные 61919
# 19:58:31 - Не получили credits данные 61919
# 19:58:34 -  Не получили details данные 61920
# /tСохранен в error_requests.txt
# 19:58:35 - Не получили keywords данные 61920
# 19:58:37 - Не получили credits данные 61920
# 19:58:51 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:58:52 -  Не получили details данные 211877
# /tСохранен в error_requests.txt
# 19:58:53 - Не получили keywords данные 211877
# 19:58:54 - Не получили credits данные 211877
# 19:58:55 -  Не получили details данные 37106
# /tСохранен в error_requests.txt
# 19:58:57 - Не получили keywords данные 37106
# 19:58:58 - Не получили credits данные 37106
# 19:59:00 -  Не получили details данные 41522
# /tСохранен в error_requests.txt
# 19:59:02 - Не получили keywords данные 41522
# 19:59:03 -  Не получили details данные 47477
# /tСохранен в error_requests.txt
# 19:59:05 -  Не получили details данные 96451
# /tСохранен в error_requests.txt
# 19:59:06 - Не получили keywords данные 96451
# 19:59:08 - Не получили credits данные 96451
# 19:59:09 -  Не получили details данные 59572
# /tСохранен в error_requests.txt
# 19:59:10 -  Не получили details данные 11788
# /tСохранен в error_requests.txt
# 19:59:13 -  Не получили details данные 40655
# /tСохранен в error_requests.txt
# 19:59:14 - Не получили keywords данные 40655
# 19:59:27 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:59:28 -  Не получили details данные 367647
# /tСохранен в error_requests.txt
# 19:59:29 - Не получили credits данные 367647
# 19:59:31 -  Не получили details данные 202241
# /tСохранен в error_requests.txt
# 19:59:32 -  Не получили details данные 36663
# /tСохранен в error_requests.txt
# 19:59:33 - Не получили keywords данные 36663
# 19:59:34 - Не получили credits данные 36663
# 19:59:35 -  Не получили details данные 71982
# /tСохранен в error_requests.txt
# 19:59:37 -  Не получили details данные 67636
# /tСохранен в error_requests.txt
# 19:59:39 - Не получили keywords данные 67636
# 19:59:40 - Не получили credits данные 67636
# 19:59:41 -  Не получили details данные 51765
# /tСохранен в error_requests.txt
# 19:59:42 - Не получили credits данные 51765
# 19:59:54 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 19:59:56 -  Не получили details данные 75375
# /tСохранен в error_requests.txt
# 19:59:57 - Не получили keywords данные 75375
# 19:59:58 - Не получили credits данные 75375
# 20:00:10 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:00:11 -  Не получили details данные 58423
# /tСохранен в error_requests.txt
# 20:00:12 - Не получили keywords данные 58423
# 20:00:13 - Не получили credits данные 58423
# 20:00:15 -  Не получили details данные 262475
# /tСохранен в error_requests.txt
# 20:00:16 - Не получили keywords данные 262475
# 20:00:17 - Не получили credits данные 262475
# 20:00:29 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:00:30 -  Не получили details данные 60364
# /tСохранен в error_requests.txt
# 20:00:31 -  Не получили details данные 20892
# /tСохранен в error_requests.txt
# 20:00:33 - Не получили keywords данные 20892
# 20:00:34 - Не получили credits данные 20892
# 20:00:35 -  Не получили details данные 192695
# /tСохранен в error_requests.txt
# 20:00:36 - Не получили keywords данные 192695
# 20:00:48 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:00:49 -  Не получили details данные 62582
# /tСохранен в error_requests.txt
# 20:00:50 - Не получили keywords данные 62582
# 20:00:52 - Не получили credits данные 62582
# 20:00:53 -  Не получили details данные 99254
# /tСохранен в error_requests.txt
# 20:00:54 - Не получили keywords данные 99254
# 20:00:55 -  Не получили details данные 470358
# /tСохранен в error_requests.txt
# 20:00:56 - Не получили keywords данные 470358
# 20:00:57 - Не получили credits данные 470358
# 20:00:59 -  Не получили details данные 26397
# /tСохранен в error_requests.txt
# 20:01:00 -  Не получили details данные 168210
# /tСохранен в error_requests.txt
# 20:01:12 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:01:13 -  Не получили details данные 46813
# /tСохранен в error_requests.txt
# 20:01:15 - Не получили keywords данные 46813
# 20:01:17 -  Не получили details данные 595378
# /tСохранен в error_requests.txt
# 20:01:19 - Не получили keywords данные 595378
# 20:01:21 - Не получили credits данные 595378
# 20:01:22 -  Не получили details данные 147269
# /tСохранен в error_requests.txt
# 20:01:24 - Не получили keywords данные 147269
# 20:01:26 - Не получили credits данные 147269
# 20:01:28 -  Не получили details данные 206997
# /tСохранен в error_requests.txt
# 20:01:30 - Не получили keywords данные 206997
# 20:01:31 -  Не получили details данные 284694
# /tСохранен в error_requests.txt
# 20:01:34 -  Не получили details данные 170359
# /tСохранен в error_requests.txt
# 20:01:35 - Не получили keywords данные 170359
# 20:01:37 - Не получили credits данные 170359
# 20:01:38 -  Не получили details данные 208988
# /tСохранен в error_requests.txt
# 20:01:40 -  Не получили details данные 83191
# /tСохранен в error_requests.txt
# 20:01:42 - Не получили keywords данные 83191
# 20:01:43 -  Не получили details данные 53803
# /tСохранен в error_requests.txt
# 20:01:45 - Не получили keywords данные 53803
# 20:01:47 - Не получили credits данные 53803
# 20:01:49 -  Не получили details данные 202043
# /tСохранен в error_requests.txt
# 20:01:51 -  Не получили details данные 216035
# /tСохранен в error_requests.txt
# 20:02:03 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:02:04 -  Не получили details данные 263946
# /tСохранен в error_requests.txt
# 20:02:06 - Не получили keywords данные 263946
# 20:02:07 -  Не получили details данные 263947
# /tСохранен в error_requests.txt
# 20:02:08 - Не получили keywords данные 263947
# 20:02:10 -  Не получили details данные 215999
# /tСохранен в error_requests.txt
# 20:02:11 - Не получили keywords данные 215999
# 20:02:12 -  Не получили details данные 117408
# /tСохранен в error_requests.txt
# 20:02:13 - Не получили keywords данные 117408
# 20:02:14 -  Не получили details данные 172538
# /tСохранен в error_requests.txt
# 20:02:15 - Не получили keywords данные 172538
# 20:02:16 - Не получили credits данные 172538
# 20:02:17 -  Не получили details данные 288293
# /tСохранен в error_requests.txt
# 20:02:19 - Не получили credits данные 288293
# 20:02:20 -  Не получили details данные 269797
# /tСохранен в error_requests.txt
# 20:02:21 - Не получили keywords данные 269797
# 20:02:23 -  Не получили details данные 51982
# /tСохранен в error_requests.txt
# 20:02:25 - Не получили keywords данные 51982
# 20:02:27 - Не получили credits данные 51982
# 20:02:29 -  Не получили details данные 147538
# /tСохранен в error_requests.txt
# 20:02:30 -  Не получили details данные 60917
# /tСохранен в error_requests.txt
# 20:02:32 - Не получили keywords данные 60917
# 20:02:34 -  Не получили details данные 69372
# /tСохранен в error_requests.txt
# 20:02:35 - Не получили keywords данные 69372
# 20:02:37 - Не получили credits данные 69372
# 20:02:38 -  Не получили details данные 62403
# /tСохранен в error_requests.txt
# 20:02:40 -  Не получили details данные 101517
# /tСохранен в error_requests.txt
# 20:02:42 - Не получили keywords данные 101517
# 20:02:44 - Не получили credits данные 101517
# 20:02:45 -  Не получили details данные 95571
# /tСохранен в error_requests.txt
# 20:02:47 - Не получили keywords данные 95571
# 20:02:49 - Не получили credits данные 95571
# 20:02:50 -  Не получили details данные 166918
# /tСохранен в error_requests.txt
# 20:02:51 - Не получили keywords данные 166918
# 20:02:52 - Не получили credits данные 166918
# 20:02:54 -  Не получили details данные 162806
# /tСохранен в error_requests.txt
# 20:02:55 - Не получили keywords данные 162806
# 20:02:56 - Не получили credits данные 162806
# 20:02:57 -  Не получили details данные 56508
# /tСохранен в error_requests.txt
# 20:02:59 - Не получили keywords данные 56508
# 20:03:00 -  Не получили details данные 89049
# /tСохранен в error_requests.txt
# 20:03:01 - Не получили keywords данные 89049
# 20:03:02 -  Не получили details данные 355551
# /tСохранен в error_requests.txt
# 20:03:03 - Не получили keywords данные 355551
# 20:03:04 - Не получили credits данные 355551
# 20:03:06 -  Не получили details данные 194668
# /tСохранен в error_requests.txt
# 20:03:07 - Не получили keywords данные 194668
# 20:03:09 -  Не получили details данные 114761
# /tСохранен в error_requests.txt
# 20:03:10 - Не получили keywords данные 114761
# 20:03:11 - Не получили credits данные 114761
# 20:03:12 -  Не получили details данные 155055
# /tСохранен в error_requests.txt
# 20:03:24 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:03:26 -  Не получили details данные 4548
# /tСохранен в error_requests.txt
# 20:03:27 -  Не получили details данные 241340
# /tСохранен в error_requests.txt
# 20:03:28 - Не получили keywords данные 241340
# 20:03:29 - Не получили credits данные 241340
# 20:03:42 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:03:44 -  Не получили details данные 63383
# /tСохранен в error_requests.txt
# 20:03:45 - Не получили credits данные 63383
# 20:03:47 -  Не получили details данные 51452
# /tСохранен в error_requests.txt
# 20:03:49 -  Не получили details данные 166986
# /tСохранен в error_requests.txt
# 20:03:51 - Не получили keywords данные 166986
# 20:03:53 - Не получили credits данные 166986
# 20:03:55 -  Не получили details данные 460870
# /tСохранен в error_requests.txt
# 20:04:07 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:04:08 -  Не получили details данные 129405
# /tСохранен в error_requests.txt
# 20:04:10 - Не получили keywords данные 129405
# 20:04:22 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:04:24 -  Не получили details данные 18231
# /tСохранен в error_requests.txt
# 20:04:25 -  Не получили details данные 252995
# /tСохранен в error_requests.txt
# 20:04:26 - Не получили keywords данные 252995
# 20:04:28 - Не получили credits данные 252995
# 20:04:40 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:04:42 -  Не получили details данные 252993
# /tСохранен в error_requests.txt
# 20:04:43 - Не получили keywords данные 252993
# 20:04:44 - Не получили credits данные 252993
# 20:04:46 -  Не получили details данные 239471
# /tСохранен в error_requests.txt
# 20:04:47 - Не получили keywords данные 239471
# 20:04:48 - Не получили credits данные 239471
# 20:04:49 -  Не получили details данные 245170
# /tСохранен в error_requests.txt
# 20:04:51 - Не получили credits данные 245170
# 20:05:03 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:05:04 -  Не получили details данные 110414
# /tСохранен в error_requests.txt
# 20:05:06 - Не получили keywords данные 110414
# 20:05:08 - Не получили credits данные 110414
# 20:05:10 -  Не получили details данные 313289
# /tСохранен в error_requests.txt
# 20:05:11 - Не получили keywords данные 313289
# 20:05:14 - Не получили credits данные 313289
# 20:05:16 -  Не получили details данные 370353
# /tСохранен в error_requests.txt
# 20:05:17 -  Не получили details данные 218277
# /tСохранен в error_requests.txt
# 20:05:18 -  Не получили details данные 257155
# /tСохранен в error_requests.txt
# 20:05:31 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:05:32 -  Не получили details данные 64047
# /tСохранен в error_requests.txt
# 20:05:33 - Не получили keywords данные 64047
# 20:05:34 -  Не получили details данные 394403
# /tСохранен в error_requests.txt
# 20:05:35 - Не получили keywords данные 394403
# 20:05:37 -  Не получили details данные 30146
# /tСохранен в error_requests.txt
# 20:05:38 -  Не получили details данные 21680
# /tСохранен в error_requests.txt
# 20:05:39 - Не получили keywords данные 21680
# 20:05:40 - Не получили credits данные 21680
# 20:05:53 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:05:54 -  Не получили details данные 67493
# /tСохранен в error_requests.txt
# 20:05:55 -  Не получили details данные 589460
# /tСохранен в error_requests.txt
# 20:05:56 - Не получили keywords данные 589460
# 20:05:57 - Не получили credits данные 589460
# 20:06:10 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:06:11 -  Не получили details данные 103081
# /tСохранен в error_requests.txt
# 20:06:12 - Не получили keywords данные 103081
# 20:06:13 -  Не получили details данные 12450
# /tСохранен в error_requests.txt
# 20:06:26 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:06:27 -  Не получили details данные 178446
# /tСохранен в error_requests.txt
# 20:06:28 -  Не получили details данные 97414
# /tСохранен в error_requests.txt
# 20:06:29 - Не получили keywords данные 97414
# 20:06:30 -  Не получили details данные 159140
# /tСохранен в error_requests.txt
# 20:06:42 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:06:44 -  Не получили details данные 64679
# /tСохранен в error_requests.txt
# 20:06:45 -  Не получили details данные 289314
# /tСохранен в error_requests.txt
# 20:06:46 -  Не получили details данные 36597
# /tСохранен в error_requests.txt
# 20:06:48 -  Не получили details данные 203766
# /tСохранен в error_requests.txt
# 20:06:49 - Не получили keywords данные 203766
# 20:06:51 -  Не получили details данные 82400
# /tСохранен в error_requests.txt
# 20:06:52 - Не получили keywords данные 82400
# 20:06:53 - Не получили credits данные 82400
# 20:07:05 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:07:07 -  Не получили details данные 276690
# /tСохранен в error_requests.txt
# 20:07:08 - Не получили keywords данные 276690
# 20:07:10 - Не получили credits данные 276690
# 20:07:22 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:07:23 -  Не получили details данные 29133
# /tСохранен в error_requests.txt
# 20:07:24 - Не получили keywords данные 29133
# 20:07:26 - Не получили credits данные 29133
# 20:07:27 -  Не получили details данные 144114
# /tСохранен в error_requests.txt
# 20:07:29 - Не получили keywords данные 144114
# 20:07:30 -  Не получили details данные 248785
# /tСохранен в error_requests.txt
# 20:07:32 - Не получили keywords данные 248785
# 20:07:34 - Не получили credits данные 248785
# 20:07:46 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:07:48 -  Не получили details данные 24486
# /tСохранен в error_requests.txt
# 20:07:50 -  Не получили details данные 2699
# /tСохранен в error_requests.txt
# 20:07:51 -  Не получили details данные 312497
# /tСохранен в error_requests.txt
# 20:07:54 -  Не получили details данные 65821
# /tСохранен в error_requests.txt
# 20:07:56 -  Не получили details данные 301231
# /tСохранен в error_requests.txt
# 20:07:57 - Не получили keywords данные 301231
# 20:07:58 - Не получили credits данные 301231
# 20:08:00 -  Не получили details данные 62836
# /tСохранен в error_requests.txt
# 20:08:01 - Не получили keywords данные 62836
# 20:08:03 -  Не получили details данные 151153
# /tСохранен в error_requests.txt
# 20:08:05 - Не получили keywords данные 151153
# 20:08:07 - Не получили credits данные 151153
# 20:08:09 -  Не получили details данные 62653
# /tСохранен в error_requests.txt
# 20:08:10 - Не получили keywords данные 62653
# 20:08:12 - Не получили credits данные 62653
# 20:08:14 -  Не получили details данные 74309
# /tСохранен в error_requests.txt
# 20:08:15 - Не получили keywords данные 74309
# 20:08:16 - Не получили credits данные 74309
# 20:08:17 -  Не получили details данные 3057
# /tСохранен в error_requests.txt
# 20:08:19 -  Не получили details данные 125458
# /tСохранен в error_requests.txt
# 20:08:20 - Не получили keywords данные 125458
# 20:08:21 -  Не получили details данные 289394
# /tСохранен в error_requests.txt
# 20:08:23 -  Не получили details данные 101660
# /tСохранен в error_requests.txt
# 20:08:36 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:08:38 -  Не получили details данные 18729
# /tСохранен в error_requests.txt
# 20:08:40 - Не получили keywords данные 18729
# 20:08:42 - Не получили credits данные 18729
# 20:08:44 -  Не получили details данные 140161
# /tСохранен в error_requests.txt
# 20:08:46 -  Не получили details данные 31183
# /tСохранен в error_requests.txt
# 20:08:47 -  Не получили details данные 63039
# /tСохранен в error_requests.txt
# 20:08:49 -  Не получили details данные 133365
# /tСохранен в error_requests.txt
# 20:08:51 - Не получили credits данные 133365
# 20:09:04 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:09:05 -  Не получили details данные 77172
# /tСохранен в error_requests.txt
# 20:09:06 -  Не получили details данные 18202
# /tСохранен в error_requests.txt
# 20:09:08 -  Не получили details данные 71461
# /tСохранен в error_requests.txt
# 20:09:09 - Не получили keywords данные 71461
# 20:09:10 -  Не получили details данные 51768
# /tСохранен в error_requests.txt
# 20:09:11 - Не получили keywords данные 51768
# 20:09:12 -  Не получили details данные 136867
# /tСохранен в error_requests.txt
# 20:09:14 - Не получили keywords данные 136867
# 20:09:15 -  Не получили details данные 299538
# /tСохранен в error_requests.txt
# 20:09:16 - Не получили keywords данные 299538
# 20:09:17 - Не получили credits данные 299538
# 20:09:18 -  Не получили details данные 202249
# /tСохранен в error_requests.txt
# 20:09:19 - Не получили keywords данные 202249
# 20:09:20 - Не получили credits данные 202249
# 20:09:22 -  Не получили details данные 74694
# /tСохранен в error_requests.txt
# 20:09:23 - Не получили keywords данные 74694
# 20:09:24 -  Не получили details данные 38611
# /tСохранен в error_requests.txt
# 20:09:25 - Не получили keywords данные 38611
# 20:09:26 -  Не получили details данные 150004
# /tСохранен в error_requests.txt
# 20:09:28 - Не получили keywords данные 150004
# 20:09:29 -  Не получили details данные 139464
# /tСохранен в error_requests.txt
# 20:09:30 - Не получили keywords данные 139464
# 20:09:31 - Не получили credits данные 139464
# 20:09:32 -  Не получили details данные 15614
# /tСохранен в error_requests.txt
# 20:09:33 -  Не получили details данные 72094
# /tСохранен в error_requests.txt
# 20:09:35 - Не получили keywords данные 72094
# 20:09:36 -  Не получили details данные 266314
# /tСохранен в error_requests.txt
# 20:09:37 - Не получили keywords данные 266314
# 20:09:38 -  Не получили details данные 180836
# /tСохранен в error_requests.txt
# 20:09:40 -  Не получили details данные 108716
# /tСохранен в error_requests.txt
# 20:09:41 -  Не получили details данные 67866
# /tСохранен в error_requests.txt
# 20:09:42 -  Не получили details данные 76162
# /tСохранен в error_requests.txt
# 20:09:43 - Не получили keywords данные 76162
# 20:09:44 - Не получили credits данные 76162
# 20:09:45 -  Не получили details данные 197592
# /tСохранен в error_requests.txt
# 20:09:46 -  Не получили details данные 25093
# /tСохранен в error_requests.txt
# 20:09:47 - Не получили keywords данные 25093
# 20:09:48 - Не получили credits данные 25093
# 20:09:50 -  Не получили details данные 13535
# /tСохранен в error_requests.txt
# 20:10:01 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:10:03 -  Не получили details данные 57622
# /tСохранен в error_requests.txt
# 20:10:04 - Не получили keywords данные 57622
# 20:10:05 - Не получили credits данные 57622
# 20:10:06 -  Не получили details данные 162864
# /tСохранен в error_requests.txt
# 20:10:08 -  Не получили details данные 67456
# /tСохранен в error_requests.txt
# 20:10:09 - Не получили keywords данные 67456
# 20:10:10 - Не получили credits данные 67456
# 20:10:11 -  Не получили details данные 53285
# /tСохранен в error_requests.txt
# 20:10:12 - Не получили keywords данные 53285
# 20:10:14 - Не получили credits данные 53285
# 20:10:26 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:10:27 -  Не получили details данные 189197
# /tСохранен в error_requests.txt
# 20:10:29 -  Не получили details данные 317384
# /tСохранен в error_requests.txt
# 20:10:30 - Не получили keywords данные 317384
# 20:10:31 -  Не получили details данные 238386
# /tСохранен в error_requests.txt
# 20:10:33 - Не получили keywords данные 238386
# 20:10:34 - Не получили credits данные 238386
# 20:10:36 -  Не получили details данные 125336
# /tСохранен в error_requests.txt
# 20:10:38 -  Не получили details данные 252063
# /tСохранен в error_requests.txt
# 20:10:40 - Не получили keywords данные 252063
# 20:10:42 - Не получили credits данные 252063
# 20:10:44 -  Не получили details данные 64123
# /tСохранен в error_requests.txt
# 20:10:45 - Не получили keywords данные 64123
# 20:10:46 -  Не получили details данные 112952
# /tСохранен в error_requests.txt
# 20:10:48 - Не получили keywords данные 112952
# 20:10:49 - Не получили credits данные 112952
# 20:10:50 -  Не получили details данные 278468
# /tСохранен в error_requests.txt
# 20:10:52 - Не получили keywords данные 278468
# 20:10:53 -  Не получили details данные 86575
# /tСохранен в error_requests.txt
# 20:10:55 - Не получили keywords данные 86575
# 20:10:56 - Не получили credits данные 86575
# 20:11:08 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:11:12 -  Не получили details данные 56511
# /tСохранен в error_requests.txt
# 20:11:13 - Не получили keywords данные 56511
# 20:11:15 -  Не получили details данные 56516
# /tСохранен в error_requests.txt
# 20:11:16 - Не получили keywords данные 56516
# 20:11:18 -  Не получили details данные 56512
# /tСохранен в error_requests.txt
# 20:11:19 - Не получили keywords данные 56512
# 20:11:21 -  Не получили details данные 56515
# /tСохранен в error_requests.txt
# 20:11:23 - Не получили keywords данные 56515
# 20:11:34 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:11:36 -  Не получили details данные 22211
# /tСохранен в error_requests.txt
# 20:11:37 -  Не получили details данные 138394
# /tСохранен в error_requests.txt
# 20:11:38 -  Не получили details данные 122023
# /tСохранен в error_requests.txt
# 20:11:39 -  Не получили details данные 158382
# /tСохранен в error_requests.txt
# 20:11:41 - Не получили keywords данные 158382
# 20:11:42 -  Не получили details данные 315010
# /tСохранен в error_requests.txt
# 20:11:43 - Не получили keywords данные 315010
# 20:12:00 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:12:01 -  Не получили details данные 160874
# /tСохранен в error_requests.txt
# 20:12:03 - Не получили credits данные 160874
# 20:12:04 -  Не получили details данные 264321
# /tСохранен в error_requests.txt
# 20:12:05 - Не получили keywords данные 264321
# 20:12:07 - Не получили credits данные 264321
# 20:12:08 -  Не получили details данные 30496
# /tСохранен в error_requests.txt
# 20:12:10 -  Не получили details данные 80527
# /tСохранен в error_requests.txt
# 20:12:12 -  Не получили details данные 56771
# /tСохранен в error_requests.txt
# 20:12:13 - Не получили keywords данные 56771
# 20:12:15 - Не получили credits данные 56771
# 20:12:17 -  Не получили details данные 321640
# /tСохранен в error_requests.txt
# 20:12:30 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:12:31 -  Не получили details данные 247668
# /tСохранен в error_requests.txt
# 20:12:32 - Не получили keywords данные 247668
# 20:12:33 - Не получили credits данные 247668
# 20:12:34 -  Не получили details данные 17669
# /tСохранен в error_requests.txt
# 20:12:36 - Не получили keywords данные 17669
# 20:12:37 -  Не получили details данные 329241
# /tСохранен в error_requests.txt
# 20:12:38 - Не получили keywords данные 329241
# 20:12:39 -  Не получили details данные 70758
# /tСохранен в error_requests.txt
# 20:12:40 -  Не получили details данные 283691
# /tСохранен в error_requests.txt
# 20:12:41 -  Не получили details данные 325557
# /tСохранен в error_requests.txt
# 20:12:42 - Не получили keywords данные 325557
# 20:12:44 - Не получили credits данные 325557
# 20:12:45 -  Не получили details данные 237718
# /tСохранен в error_requests.txt
# 20:12:47 - Не получили keywords данные 237718
# 20:12:48 - Не получили credits данные 237718
# 20:12:49 -  Не получили details данные 141702
# /tСохранен в error_requests.txt
# 20:12:50 - Не получили keywords данные 141702
# 20:12:51 - Не получили credits данные 141702
# 20:12:52 -  Не получили details данные 168219
# /tСохранен в error_requests.txt
# 20:12:53 - Не получили keywords данные 168219
# 20:12:55 - Не получили credits данные 168219
# 20:12:56 -  Не получили details данные 131934
# /tСохранен в error_requests.txt
# 20:12:57 - Не получили keywords данные 131934
# 20:12:58 -  Не получили details данные 216037
# /tСохранен в error_requests.txt
# 20:12:59 - Не получили keywords данные 216037
# 20:13:00 -  Не получили details данные 55229
# /tСохранен в error_requests.txt
# 20:13:01 -  Не получили details данные 44937
# /tСохранен в error_requests.txt
# 20:13:03 - Не получили keywords данные 44937
# 20:13:04 -  Не получили details данные 335676
# /tСохранен в error_requests.txt
# 20:13:05 - Не получили keywords данные 335676
# 20:13:06 -  Не получили details данные 345896
# /tСохранен в error_requests.txt
# 20:13:07 - Не получили keywords данные 345896
# 20:13:08 - Не получили credits данные 345896
# 20:13:09 -  Не получили details данные 293238
# /tСохранен в error_requests.txt
# 20:13:10 - Не получили keywords данные 293238
# 20:13:12 -  Не получили details данные 53774
# /tСохранен в error_requests.txt
# 20:13:13 -  Не получили details данные 85702
# /tСохранен в error_requests.txt
# 20:13:14 - Не получили keywords данные 85702
# 20:13:15 -  Не получили details данные 19792
# /tСохранен в error_requests.txt
# 20:13:16 -  Не получили details данные 53875
# /tСохранен в error_requests.txt
# 20:13:28 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:13:29 -  Не получили details данные 37668
# /tСохранен в error_requests.txt
# 20:13:30 - Не получили keywords данные 37668
# 20:13:31 -  Не получили details данные 282247
# /tСохранен в error_requests.txt
# 20:13:33 - Не получили keywords данные 282247
# 20:13:34 -  Не получили details данные 341984
# /tСохранен в error_requests.txt
# 20:13:35 - Не получили keywords данные 341984
# 20:13:36 -  Не получили details данные 12188
# /tСохранен в error_requests.txt
# 20:13:37 - Не получили keywords данные 12188
# 20:13:38 - Не получили credits данные 12188
# 20:13:39 -  Не получили details данные 109515
# /tСохранен в error_requests.txt
# 20:13:41 - Не получили keywords данные 109515
# 20:13:52 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:13:53 -  Не получили details данные 338850
# /tСохранен в error_requests.txt
# 20:13:54 - Не получили keywords данные 338850
# 20:13:56 - Не получили credits данные 338850
# 20:14:07 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:14:09 -  Не получили details данные 65973
# /tСохранен в error_requests.txt
# 20:14:11 -  Не получили details данные 344560
# /tСохранен в error_requests.txt
# 20:14:12 - Не получили keywords данные 344560
# 20:14:24 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:14:25 -  Не получили details данные 206514
# /tСохранен в error_requests.txt
# 20:14:26 -  Не получили details данные 62931
# /tСохранен в error_requests.txt
# 20:14:28 - Не получили keywords данные 62931
# 20:14:30 -  Не получили details данные 191476
# /tСохранен в error_requests.txt
# 20:14:32 -  Не получили details данные 141334
# /tСохранен в error_requests.txt
# 20:14:33 - Не получили keywords данные 141334
# 20:14:35 - Не получили credits данные 141334
# 20:14:36 -  Не получили details данные 108497
# /tСохранен в error_requests.txt
# 20:14:39 - Не получили keywords данные 108497
# 20:14:40 - Не получили credits данные 108497
# 20:14:42 -  Не получили details данные 114691
# /tСохранен в error_requests.txt
# 20:14:44 - Не получили keywords данные 114691
# 20:14:45 - Не получили credits данные 114691
# 20:14:47 -  Не получили details данные 99022
# /tСохранен в error_requests.txt
# 20:14:48 - Не получили keywords данные 99022
# 20:14:50 -  Не получили details данные 353653
# /tСохранен в error_requests.txt
# 20:14:51 - Не получили keywords данные 353653
# 20:14:52 -  Не получили details данные 25180
# /tСохранен в error_requests.txt
# 20:14:53 - Не получили keywords данные 25180
# 20:15:05 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:15:06 -  Не получили details данные 278604
# /tСохранен в error_requests.txt
# 20:15:07 -  Не получили details данные 246699
# /tСохранен в error_requests.txt
# 20:15:08 -  Не получили details данные 134777
# /tСохранен в error_requests.txt
# 20:15:09 - Не получили keywords данные 134777
# 20:15:11 -  Не получили details данные 180152
# /tСохранен в error_requests.txt
# 20:15:12 - Не получили keywords данные 180152
# 20:15:13 -  Не получили details данные 329637
# /tСохранен в error_requests.txt
# 20:15:15 - Не получили keywords данные 329637
# 20:15:17 -  Не получили details данные 265758
# /tСохранен в error_requests.txt
# 20:15:18 - Не получили keywords данные 265758
# 20:15:20 -  Не получили details данные 281124
# /tСохранен в error_requests.txt
# 20:15:22 - Не получили keywords данные 281124
# 20:15:23 -  Не получили details данные 357130
# /tСохранен в error_requests.txt
# 20:15:25 - Не получили keywords данные 357130
# 20:15:36 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:15:37 -  Не получили details данные 357143
# /tСохранен в error_requests.txt
# 20:15:38 - Не получили keywords данные 357143
# 20:15:41 - Не получили credits данные 357143
# 20:15:43 -  Не получили details данные 11204
# /tСохранен в error_requests.txt
# 20:15:44 -  Не получили details данные 268009
# /tСохранен в error_requests.txt
# 20:15:45 - Не получили keywords данные 268009
# 20:15:46 -  Не получили details данные 357935
# /tСохранен в error_requests.txt
# 20:15:47 - Не получили keywords данные 357935
# 20:16:00 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:16:01 -  Не получили details данные 263570
# /tСохранен в error_requests.txt
# 20:16:02 - Не получили keywords данные 263570
# 20:16:14 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:16:15 -  Не получили details данные 256515
# /tСохранен в error_requests.txt
# 20:16:16 - Не получили keywords данные 256515
# 20:16:17 - Не получили credits данные 256515
# 20:16:31 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:16:33 -  Не получили details данные 27934
# /tСохранен в error_requests.txt
# 20:16:34 - Не получили keywords данные 27934
# 20:16:36 -  Не получили details данные 200813
# /tСохранен в error_requests.txt
# 20:16:37 -  Не получили details данные 30294
# /tСохранен в error_requests.txt
# 20:16:39 -  Не получили details данные 77197
# /tСохранен в error_requests.txt
# 20:16:40 -  Не получили details данные 16854
# /tСохранен в error_requests.txt
# 20:16:41 -  Не получили details данные 256955
# /tСохранен в error_requests.txt
# 20:16:42 - Не получили keywords данные 256955
# 20:16:43 - Не получили credits данные 256955
# 20:16:56 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:16:58 -  Не получили details данные 143769
# /tСохранен в error_requests.txt
# 20:16:59 - Не получили keywords данные 143769
# 20:17:01 -  Не получили details данные 172577
# /tСохранен в error_requests.txt
# 20:17:02 -  Не получили details данные 47084
# /tСохранен в error_requests.txt
# 20:17:03 -  Не получили details данные 292739
# /tСохранен в error_requests.txt
# 20:17:05 - Не получили keywords данные 292739
# 20:17:06 - Не получили credits данные 292739
# 20:17:08 -  Не получили details данные 47761
# /tСохранен в error_requests.txt
# 20:17:10 -  Не получили details данные 99708
# /tСохранен в error_requests.txt
# 20:17:11 - Не получили keywords данные 99708
# 20:17:12 -  Не получили details данные 72792
# /tСохранен в error_requests.txt
# 20:17:14 - Не получили keywords данные 72792
# 20:17:15 - Не получили credits данные 72792
# 20:17:16 -  Не получили details данные 58207
# /tСохранен в error_requests.txt
# 20:17:18 -  Не получили details данные 101833
# /tСохранен в error_requests.txt
# 20:17:20 - Не получили keywords данные 101833
# 20:17:21 - Не получили credits данные 101833
# 20:17:23 -  Не получили details данные 64042
# /tСохранен в error_requests.txt
# 20:17:24 -  Не получили details данные 51129
# /tСохранен в error_requests.txt
# 20:17:26 - Не получили keywords данные 51129
# 20:17:27 -  Не получили details данные 74751
# /tСохранен в error_requests.txt
# 20:17:28 - Не получили keywords данные 74751
# 20:17:30 - Не получили credits данные 74751
# 20:17:32 -  Не получили details данные 137587
# /tСохранен в error_requests.txt
# 20:17:33 - Не получили keywords данные 137587
# 20:17:35 - Не получили credits данные 137587
# 20:17:37 -  Не получили details данные 337751
# /tСохранен в error_requests.txt
# 20:17:38 -  Не получили details данные 293603
# /tСохранен в error_requests.txt
# 20:17:40 -  Не получили details данные 127605
# /tСохранен в error_requests.txt
# 20:17:42 - Не получили keywords данные 127605
# 20:17:44 - Не получили credits данные 127605
# 20:17:55 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:17:57 -  Не получили details данные 38430
# /tСохранен в error_requests.txt
# 20:18:08 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:18:09 -  Не получили details данные 72093
# /tСохранен в error_requests.txt
# 20:18:11 - Не получили keywords данные 72093
# 20:18:13 -  Не получили details данные 72095
# /tСохранен в error_requests.txt
# 20:18:14 - Не получили keywords данные 72095
# 20:18:25 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:18:26 -  Не получили details данные 60199
# /tСохранен в error_requests.txt
# 20:18:28 -  Не получили details данные 353462
# /tСохранен в error_requests.txt
# 20:18:29 - Не получили keywords данные 353462
# 20:18:30 -  Не получили details данные 60836
# /tСохранен в error_requests.txt
# 20:18:32 - Не получили keywords данные 60836
# 20:18:33 -  Не получили details данные 253426
# /tСохранен в error_requests.txt
# 20:18:34 - Не получили keywords данные 253426
# 20:18:36 - Не получили credits данные 253426
# 20:18:38 -  Не получили details данные 219466
# /tСохранен в error_requests.txt
# 20:18:39 -  Не получили details данные 194079
# /tСохранен в error_requests.txt
# 20:18:42 -  Не получили details данные 345575
# /tСохранен в error_requests.txt
# 20:18:53 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:18:54 -  Не получили details данные 119149
# /tСохранен в error_requests.txt
# 20:18:56 - Не получили keywords данные 119149
# 20:18:57 - Не получили credits данные 119149
# 20:18:59 -  Не получили details данные 213756
# /tСохранен в error_requests.txt
# 20:19:01 - Не получили keywords данные 213756
# 20:19:04 - Не получили credits данные 213756
# 20:19:06 -  Не получили details данные 213755
# /tСохранен в error_requests.txt
# 20:19:08 - Не получили keywords данные 213755
# 20:19:19 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:19:21 -  Не получили details данные 152539
# /tСохранен в error_requests.txt
# 20:19:22 -  Не получили details данные 327016
# /tСохранен в error_requests.txt
# 20:19:23 -  Не получили details данные 369879
# /tСохранен в error_requests.txt
# 20:19:25 - Не получили keywords данные 369879
# 20:19:27 - Не получили credits данные 369879
# 20:19:29 -  Не получили details данные 30922
# /tСохранен в error_requests.txt
# 20:19:30 - Не получили keywords данные 30922
# 20:19:31 -  Не получили details данные 366492
# /tСохранен в error_requests.txt
# 20:19:33 - Не получили keywords данные 366492
# 20:19:35 - Не получили credits данные 366492
# 20:19:36 -  Не получили details данные 373162
# /tСохранен в error_requests.txt
# 20:19:38 - Не получили keywords данные 373162
# 20:19:40 - Не получили credits данные 373162
# 20:19:42 -  Не получили details данные 263953
# /tСохранен в error_requests.txt
# 20:19:44 - Не получили keywords данные 263953
# 20:19:45 - Не получили credits данные 263953
# 20:19:47 -  Не получили details данные 303950
# /tСохранен в error_requests.txt
# 20:19:49 - Не получили keywords данные 303950
# 20:19:50 - Не получили credits данные 303950
# 20:20:02 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:20:03 -  Не получили details данные 79280
# /tСохранен в error_requests.txt
# 20:20:04 - Не получили keywords данные 79280
# 20:20:05 - Не получили credits данные 79280
# 20:20:16 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:20:18 -  Не получили details данные 187006
# /tСохранен в error_requests.txt
# 20:20:19 - Не получили keywords данные 187006
# 20:20:21 - Не получили credits данные 187006
# 20:20:23 -  Не получили details данные 373977
# /tСохранен в error_requests.txt
# 20:20:25 - Не получили keywords данные 373977
# 20:20:26 -  Не получили details данные 373357
# /tСохранен в error_requests.txt
# 20:20:28 - Не получили keywords данные 373357
# 20:20:29 - Не получили credits данные 373357
# 20:20:30 -  Не получили details данные 211354
# /tСохранен в error_requests.txt
# 20:20:32 -  Не получили details данные 73468
# /tСохранен в error_requests.txt
# 20:20:34 - Не получили keywords данные 73468
# 20:20:35 - Не получили credits данные 73468
# 20:20:36 -  Не получили details данные 119209
# /tСохранен в error_requests.txt
# 20:20:37 - Не получили keywords данные 119209
# 20:20:39 - Не получили credits данные 119209
# 20:20:40 -  Не получили details данные 360626
# /tСохранен в error_requests.txt
# 20:20:41 - Не получили keywords данные 360626
# 20:20:42 - Не получили credits данные 360626
# 20:20:43 -  Не получили details данные 376823
# /tСохранен в error_requests.txt
# 20:20:45 - Не получили credits данные 376823
# 20:20:46 -  Не получили details данные 249926
# /tСохранен в error_requests.txt
# 20:20:47 -  Не получили details данные 313985
# /tСохранен в error_requests.txt
# 20:20:48 - Не получили keywords данные 313985
# 20:20:50 - Не получили credits данные 313985
# 20:21:01 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:21:03 -  Не получили details данные 251546
# /tСохранен в error_requests.txt
# 20:21:05 - Не получили keywords данные 251546
# 20:21:07 - Не получили credits данные 251546
# 20:21:09 -  Не получили details данные 56588
# /tСохранен в error_requests.txt
# 20:21:11 - Не получили keywords данные 56588
# 20:21:13 - Не получили credits данные 56588
# 20:21:15 -  Не получили details данные 211845
# /tСохранен в error_requests.txt
# 20:21:27 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:21:29 -  Не получили details данные 377136
# /tСохранен в error_requests.txt
# 20:21:32 - Не получили keywords данные 377136
# 20:21:34 -  Не получили details данные 139777
# /tСохранен в error_requests.txt
# 20:21:35 -  Не получили details данные 333040
# /tСохранен в error_requests.txt
# 20:21:36 - Не получили keywords данные 333040
# 20:21:37 - Не получили credits данные 333040
# 20:21:48 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:21:49 -  Не получили details данные 376681
# /tСохранен в error_requests.txt
# 20:21:50 -  Не получили details данные 280617
# /tСохранен в error_requests.txt
# 20:21:51 -  Не получили details данные 379951
# /tСохранен в error_requests.txt
# 20:21:53 - Не получили keywords данные 379951
# 20:21:54 - Не получили credits данные 379951
# 20:21:55 -  Не получили details данные 378779
# /tСохранен в error_requests.txt
# 20:21:56 - Не получили keywords данные 378779
# 20:21:57 - Не получили credits данные 378779
# 20:21:58 -  Не получили details данные 354297
# /tСохранен в error_requests.txt
# 20:22:00 - Не получили keywords данные 354297
# 20:22:01 - Не получили credits данные 354297
# 20:22:02 -  Не получили details данные 52236
# /tСохранен в error_requests.txt
# 20:22:03 - Не получили credits данные 52236
# 20:22:04 -  Не получили details данные 293471
# /tСохранен в error_requests.txt
# 20:22:05 -  Не получили details данные 161535
# /tСохранен в error_requests.txt
# 20:22:06 - Не получили keywords данные 161535
# 20:22:07 - Не получили credits данные 161535
# 20:22:18 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:22:19 -  Не получили details данные 200414
# /tСохранен в error_requests.txt
# 20:22:21 - Не получили keywords данные 200414
# 20:22:22 - Не получили credits данные 200414
# 20:22:23 -  Не получили details данные 35335
# /tСохранен в error_requests.txt
# 20:22:25 - Не получили keywords данные 35335
# 20:22:28 - Не получили credits данные 35335
# 20:22:39 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:22:40 -  Не получили details данные 155678
# /tСохранен в error_requests.txt
# 20:22:41 - Не получили keywords данные 155678
# 20:22:42 - Не получили credits данные 155678
# 20:22:43 -  Не получили details данные 208947
# /tСохранен в error_requests.txt
# 20:22:44 - Не получили credits данные 208947
# 20:22:45 -  Не получили details данные 371758
# /tСохранен в error_requests.txt
# 20:22:47 - Не получили credits данные 371758
# 20:22:48 -  Не получили details данные 62241
# /tСохранен в error_requests.txt
# 20:22:49 - Не получили keywords данные 62241
# 20:22:50 -  Не получили details данные 198993
# /tСохранен в error_requests.txt
# 20:22:51 - Не получили keywords данные 198993
# 20:22:52 -  Не получили details данные 341224
# /tСохранен в error_requests.txt
# 20:22:54 - Не получили keywords данные 341224
# 20:22:56 - Не получили credits данные 341224
# 20:22:58 -  Не получили details данные 153397
# /tСохранен в error_requests.txt
# 20:23:00 -  Не получили details данные 385965
# /tСохранен в error_requests.txt
# 20:23:02 - Не получили keywords данные 385965
# 20:23:04 - Не получили credits данные 385965
# 20:23:15 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:23:17 -  Не получили details данные 202831
# /tСохранен в error_requests.txt
# 20:23:18 -  Не получили details данные 50942
# /tСохранен в error_requests.txt
# 20:23:20 - Не получили keywords данные 50942
# 20:23:22 -  Не получили details данные 109606
# /tСохранен в error_requests.txt
# 20:23:23 - Не получили keywords данные 109606
# 20:23:25 - Не получили credits данные 109606
# 20:23:26 -  Не получили details данные 109346
# /tСохранен в error_requests.txt
# 20:23:27 - Не получили keywords данные 109346
# 20:23:29 - Не получили credits данные 109346
# 20:23:31 -  Не получили details данные 200558
# /tСохранен в error_requests.txt
# 20:23:32 -  Не получили details данные 357125
# /tСохранен в error_requests.txt
# 20:23:34 - Не получили keywords данные 357125
# 20:23:46 - Сохранение датасетов. Сейчас есть 5063 пропусков
# 20:23:48 -  Не получили details данные 347938
# /tСохранен в error_requests.txt
# 20:23:50 -  Не получили details данные 391997
# /tСохранен в error_requests.txt
# 20:23:51 - Не получили keywords данные 391997
# 20:23:53 -  Не получили details данные 56128
# /tСохранен в error_requests.txt
# 20:23:54 - Не получили keywords данные 56128
# 20:23:56 - Не получили credits данные 56128
# 20:23:58 -  Не получили details данные 25843
# /tСохранен в error_requests.txt
# 20:23:59 -  Не получили details данные 277098
# /tСохранен в error_requests.txt
# 20:24:00 - Не получили keywords данные 277098
# 20:24:01 -  Не получили details данные 93734
# ...
# 04:25:51 - Сохранение датасетов. Сейчас есть 1019 пропусков
# 04:26:46 - Сохранение датасетов. Сейчас есть 1010 пропусков
# 04:28:09 - Сохранение датасетов. Сейчас есть 992 пропусков
# 04:28:40 -  Не получили details данные 536927
# /tСохранен в error_requests.txt
# 04:28:41 - Не получили keywords данные 536927
# 04:28:42 - Не получили credits данные 536927
# 04:28:43 -  Не получили details данные 529239
# /tСохранен в error_requests.txt
# 04:28:44 - Не получили keywords данные 529239
# 04:28:45 - Не получили credits данные 529239
# 04:28:47 -  Не получили details данные 535484
# /tСохранен в error_requests.txt
# 04:28:48 - Не получили keywords данные 535484
# 04:28:49 - Не получили credits данные 535484
# 04:28:50 -  Не получили details данные 551874
# /tСохранен в error_requests.txt
# 04:28:51 - Не получили keywords данные 551874
# 04:28:52 - Не получили credits данные 551874
# 04:28:53 -  Не получили details данные 557891
# /tСохранен в error_requests.txt
# 04:28:54 - Не получили keywords данные 557891
# 04:28:55 - Не получили credits данные 557891
# 04:28:56 -  Не получили details данные 496541
# /tСохранен в error_requests.txt
# 04:28:57 - Не получили keywords данные 496541
# 04:28:59 - Не получили credits данные 496541
# 04:29:00 -  Не получили details данные 414278
# /tСохранен в error_requests.txt
# 04:29:02 - Не получили keywords данные 414278
# 04:29:03 - Не получили credits данные 414278
# 04:29:04 -  Не получили details данные 427094
# /tСохранен в error_requests.txt
# 04:29:05 - Не получили keywords данные 427094
# 04:29:07 - Не получили credits данные 427094
# 04:29:08 -  Не получили details данные 536376
# /tСохранен в error_requests.txt
# 04:29:10 - Не получили keywords данные 536376
# 04:29:11 - Не получили credits данные 536376
# 04:29:13 -  Не получили details данные 518312
# /tСохранен в error_requests.txt
# 04:29:15 - Не получили keywords данные 518312
# 04:29:16 - Не получили credits данные 518312
# 04:29:17 -  Не получили details данные 565184
# /tСохранен в error_requests.txt
# 04:29:19 - Не получили keywords данные 565184
# 04:29:20 - Не получили credits данные 565184
# 04:29:21 -  Не получили details данные 560701
# /tСохранен в error_requests.txt
# 04:29:23 - Не получили keywords данные 560701
# 04:29:25 - Не получили credits данные 560701
# 04:29:26 -  Не получили details данные 566492
# /tСохранен в error_requests.txt
# 04:29:27 - Не получили keywords данные 566492
# 04:29:29 - Не получили credits данные 566492
# 04:29:30 -  Не получили details данные 562155
# /tСохранен в error_requests.txt
# 04:29:31 - Не получили keywords данные 562155
# 04:29:33 - Не получили credits данные 562155
# 04:29:45 - Сохранение датасетов. Сейчас есть 983 пропусков
# 04:29:46 -  Не получили details данные 319315
# /tСохранен в error_requests.txt
# 04:29:47 - Не получили keywords данные 319315
# 04:29:49 - Не получили credits данные 319315
# 04:30:01 - Сохранение датасетов. Сейчас есть 983 пропусков
# 04:30:03 -  Не получили details данные 499928
# /tСохранен в error_requests.txt
# 04:30:04 - Не получили keywords данные 499928
# 04:30:05 - Не получили credits данные 499928
# 04:30:06 -  Не получили details данные 569293
# /tСохранен в error_requests.txt
# 04:30:07 - Не получили keywords данные 569293
# 04:30:09 - Не получили credits данные 569293
# 04:30:13 -  Не получили details данные 139295
# /tСохранен в error_requests.txt
# 04:30:15 - Не получили keywords данные 139295
# 04:30:17 - Не получили credits данные 139295
# 04:30:29 - Сохранение датасетов. Сейчас есть 982 пропусков
# 04:30:30 -  Не получили details данные 459629
# /tСохранен в error_requests.txt
# 04:30:33 - Не получили keywords данные 459629
# 04:30:34 - Не получили credits данные 459629
# 04:30:35 -  Не получили details данные 161552
# /tСохранен в error_requests.txt
# 04:30:36 - Не получили keywords данные 161552
# 04:30:37 - Не получили credits данные 161552
# 04:30:40 -  Не получили details данные 409776
# /tСохранен в error_requests.txt
# 04:30:41 - Не получили keywords данные 409776
# 04:30:42 - Не получили credits данные 409776
# 04:30:43 -  Не получили details данные 516383
# /tСохранен в error_requests.txt
# 04:30:44 - Не получили keywords данные 516383
# 04:30:45 - Не получили credits данные 516383
# 04:30:47 -  Не получили details данные 586129
# /tСохранен в error_requests.txt
# 04:30:48 - Не получили keywords данные 586129
# 04:30:49 - Не получили credits данные 586129
# 04:30:50 -  Не получили details данные 414401
# /tСохранен в error_requests.txt
# 04:30:51 - Не получили keywords данные 414401
# 04:30:52 - Не получили credits данные 414401
# 04:30:53 -  Не получили details данные 62444
# /tСохранен в error_requests.txt
# 04:30:54 - Не получили keywords данные 62444
# 04:30:55 - Не получили credits данные 62444
# 04:30:56 -  Не получили details данные 53986
# /tСохранен в error_requests.txt
# 04:30:57 - Не получили keywords данные 53986
# 04:30:58 - Не получили credits данные 53986
# 04:30:59 -  Не получили details данные 384975
# /tСохранен в error_requests.txt
# 04:31:00 - Не получили keywords данные 384975
# 04:31:02 - Не получили credits данные 384975
# 04:31:13 - Сохранение датасетов. Сейчас есть 981 пропусков
# 04:31:14 -  Не получили details данные 465803
# /tСохранен в error_requests.txt
# 04:31:15 - Не получили keywords данные 465803
# 04:31:16 - Не получили credits данные 465803
# 04:31:17 -  Не получили details данные 467080
# /tСохранен в error_requests.txt
# 04:31:19 - Не получили keywords данные 467080
# 04:31:20 - Не получили credits данные 467080
# 04:31:32 - Сохранение датасетов. Сейчас есть 981 пропусков
# 04:31:35 -  Не получили details данные 578715
# /tСохранен в error_requests.txt
# 04:31:36 - Не получили keywords данные 578715
# 04:31:37 - Не получили credits данные 578715
# 04:31:49 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:31:50 -  Не получили details данные 589023
# /tСохранен в error_requests.txt
# 04:31:51 - Не получили keywords данные 589023
# 04:31:52 - Не получили credits данные 589023
# 04:31:53 -  Не получили details данные 576676
# /tСохранен в error_requests.txt
# 04:31:54 - Не получили keywords данные 576676
# 04:31:55 - Не получили credits данные 576676
# 04:31:56 -  Не получили details данные 590710
# /tСохранен в error_requests.txt
# 04:31:57 - Не получили keywords данные 590710
# 04:31:58 - Не получили credits данные 590710
# 04:32:10 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:32:13 -  Не получили details данные 594750
# /tСохранен в error_requests.txt
# 04:32:14 - Не получили keywords данные 594750
# 04:32:16 - Не получили credits данные 594750
# 04:32:27 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:32:29 -  Не получили details данные 288572
# /tСохранен в error_requests.txt
# 04:32:31 - Не получили keywords данные 288572
# 04:32:32 - Не получили credits данные 288572
# 04:32:34 -  Не получили details данные 595124
# /tСохранен в error_requests.txt
# 04:32:35 - Не получили keywords данные 595124
# 04:32:37 - Не получили credits данные 595124
# 04:32:39 -  Не получили details данные 306732
# /tСохранен в error_requests.txt
# 04:32:40 - Не получили keywords данные 306732
# 04:32:42 - Не получили credits данные 306732
# 04:32:43 -  Не получили details данные 328303
# /tСохранен в error_requests.txt
# 04:32:44 - Не получили keywords данные 328303
# 04:32:45 - Не получили credits данные 328303
# 04:32:47 -  Не получили details данные 258209
# /tСохранен в error_requests.txt
# 04:32:48 - Не получили keywords данные 258209
# 04:32:50 - Не получили credits данные 258209
# 04:32:51 -  Не получили details данные 39500
# /tСохранен в error_requests.txt
# 04:32:53 - Не получили keywords данные 39500
# 04:32:54 - Не получили credits данные 39500
# 04:33:06 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:33:07 -  Не получили details данные 502575
# /tСохранен в error_requests.txt
# 04:33:08 - Не получили keywords данные 502575
# 04:33:09 - Не получили credits данные 502575
# 04:33:21 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:33:23 -  Не получили details данные 263030
# /tСохранен в error_requests.txt
# 04:33:25 - Не получили keywords данные 263030
# 04:33:27 - Не получили credits данные 263030
# 04:33:39 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:33:40 -  Не получили details данные 297644
# /tСохранен в error_requests.txt
# 04:33:42 - Не получили keywords данные 297644
# 04:33:43 - Не получили credits данные 297644
# 04:33:44 -  Не получили details данные 292307
# /tСохранен в error_requests.txt
# 04:33:45 - Не получили keywords данные 292307
# 04:33:46 - Не получили credits данные 292307
# 04:33:47 -  Не получили details данные 332218
# /tСохранен в error_requests.txt
# 04:33:48 - Не получили keywords данные 332218
# 04:33:50 - Не получили credits данные 332218
# 04:33:51 -  Не получили details данные 363999
# /tСохранен в error_requests.txt
# 04:33:52 - Не получили keywords данные 363999
# 04:33:53 - Не получили credits данные 363999
# 04:33:54 -  Не получили details данные 455166
# /tСохранен в error_requests.txt
# 04:33:55 - Не получили keywords данные 455166
# 04:33:56 - Не получили credits данные 455166
# 04:33:57 -  Не получили details данные 455419
# /tСохранен в error_requests.txt
# 04:33:59 - Не получили keywords данные 455419
# 04:34:00 - Не получили credits данные 455419
# 04:34:01 -  Не получили details данные 593778
# /tСохранен в error_requests.txt
# 04:34:02 - Не получили keywords данные 593778
# 04:34:03 - Не получили credits данные 593778
# 04:34:04 -  Не получили details данные 346387
# /tСохранен в error_requests.txt
# 04:34:05 - Не получили keywords данные 346387
# 04:34:06 - Не получили credits данные 346387
# 04:34:07 -  Не получили details данные 566549
# /tСохранен в error_requests.txt
# 04:34:09 - Не получили keywords данные 566549
# 04:34:10 - Не получили credits данные 566549
# 04:34:11 -  Не получили details данные 253773
# /tСохранен в error_requests.txt
# 04:34:12 - Не получили keywords данные 253773
# 04:34:13 - Не получили credits данные 253773
# 04:34:14 -  Не получили details данные 614750
# /tСохранен в error_requests.txt
# 04:34:15 - Не получили keywords данные 614750
# 04:34:16 - Не получили credits данные 614750
# 04:34:28 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:34:29 -  Не получили details данные 609703
# /tСохранен в error_requests.txt
# 04:34:30 - Не получили keywords данные 609703
# 04:34:31 - Не получили credits данные 609703
# 04:34:33 -  Не получили details данные 466750
# /tСохранен в error_requests.txt
# 04:34:34 - Не получили keywords данные 466750
# 04:34:35 - Не получили credits данные 466750
# 04:34:47 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:34:48 -  Не получили details данные 451364
# /tСохранен в error_requests.txt
# 04:34:49 - Не получили keywords данные 451364
# 04:34:50 - Не получили credits данные 451364
# 04:34:51 -  Не получили details данные 525206
# /tСохранен в error_requests.txt
# 04:34:52 - Не получили keywords данные 525206
# 04:34:53 - Не получили credits данные 525206
# 04:34:54 -  Не получили details данные 607517
# /tСохранен в error_requests.txt
# 04:34:56 - Не получили keywords данные 607517
# 04:34:57 - Не получили credits данные 607517
# 04:34:58 -  Не получили details данные 622077
# /tСохранен в error_requests.txt
# 04:34:59 - Не получили keywords данные 622077
# 04:35:00 - Не получили credits данные 622077
# 04:35:01 -  Не получили details данные 609714
# /tСохранен в error_requests.txt
# 04:35:02 - Не получили keywords данные 609714
# 04:35:03 - Не получили credits данные 609714
# 04:35:04 -  Не получили details данные 593848
# /tСохранен в error_requests.txt
# 04:35:06 - Не получили keywords данные 593848
# 04:35:07 - Не получили credits данные 593848
# 04:35:08 -  Не получили details данные 567273
# /tСохранен в error_requests.txt
# 04:35:09 - Не получили keywords данные 567273
# 04:35:10 - Не получили credits данные 567273
# 04:35:11 -  Не получили details данные 573195
# /tСохранен в error_requests.txt
# 04:35:12 - Не получили keywords данные 573195
# 04:35:13 - Не получили credits данные 573195
# 04:35:25 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:35:26 -  Не получили details данные 484855
# /tСохранен в error_requests.txt
# 04:35:28 - Не получили keywords данные 484855
# 04:35:29 - Не получили credits данные 484855
# 04:35:41 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:35:43 -  Не получили details данные 574905
# /tСохранен в error_requests.txt
# 04:35:44 - Не получили keywords данные 574905
# 04:35:46 - Не получили credits данные 574905
# 04:35:58 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:35:59 -  Не получили details данные 611478
# /tСохранен в error_requests.txt
# 04:36:01 - Не получили keywords данные 611478
# 04:36:03 - Не получили credits данные 611478
# 04:36:05 -  Не получили details данные 577625
# /tСохранен в error_requests.txt
# 04:36:07 - Не получили keywords данные 577625
# 04:36:09 - Не получили credits данные 577625
# 04:36:20 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:36:22 -  Не получили details данные 633190
# /tСохранен в error_requests.txt
# 04:36:23 - Не получили keywords данные 633190
# 04:36:24 - Не получили credits данные 633190
# 04:36:36 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:36:37 -  Не получили details данные 360086
# /tСохранен в error_requests.txt
# 04:36:39 - Не получили keywords данные 360086
# 04:36:40 - Не получили credits данные 360086
# 04:36:43 -  Не получили details данные 92246
# /tСохранен в error_requests.txt
# 04:36:44 - Не получили keywords данные 92246
# 04:36:45 - Не получили credits данные 92246
# 04:36:47 -  Не получили details данные 210590
# /tСохранен в error_requests.txt
# 04:36:49 - Не получили keywords данные 210590
# 04:36:51 - Не получили credits данные 210590
# 04:37:03 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:37:04 -  Не получили details данные 629861
# /tСохранен в error_requests.txt
# 04:37:05 - Не получили keywords данные 629861
# 04:37:06 - Не получили credits данные 629861
# 04:37:07 -  Не получили details данные 636391
# /tСохранен в error_requests.txt
# 04:37:08 - Не получили keywords данные 636391
# 04:37:09 - Не получили credits данные 636391
# 04:37:10 -  Не получили details данные 224302
# /tСохранен в error_requests.txt
# 04:37:11 - Не получили keywords данные 224302
# 04:37:12 - Не получили credits данные 224302
# 04:37:13 -  Не получили details данные 334912
# /tСохранен в error_requests.txt
# 04:37:14 - Не получили keywords данные 334912
# 04:37:16 - Не получили credits данные 334912
# 04:37:17 -  Не получили details данные 644672
# /tСохранен в error_requests.txt
# 04:37:18 - Не получили keywords данные 644672
# 04:37:19 - Не получили credits данные 644672
# 04:37:20 -  Не получили details данные 242550
# /tСохранен в error_requests.txt
# 04:37:21 - Не получили keywords данные 242550
# 04:37:22 - Не получили credits данные 242550
# 04:37:34 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:37:35 -  Не получили details данные 431510
# /tСохранен в error_requests.txt
# 04:37:36 - Не получили keywords данные 431510
# 04:37:37 - Не получили credits данные 431510
# 04:37:49 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:37:50 -  Не получили details данные 401707
# /tСохранен в error_requests.txt
# 04:37:52 - Не получили keywords данные 401707
# 04:37:53 - Не получили credits данные 401707
# 04:37:54 -  Не получили details данные 401885
# /tСохранен в error_requests.txt
# 04:37:55 - Не получили keywords данные 401885
# 04:37:56 - Не получили credits данные 401885
# 04:38:08 - Сохранение датасетов. Сейчас есть 980 пропусков
# 04:38:09 -  Не получили details данные 421602
# /tСохранен в error_requests.txt
# 04:38:10 - Не получили keywords данные 421602
# 04:38:11 - Не получили credits данные 421602
# 04:38:12 -  Не получили details данные 656594
# /tСохранен в error_requests.txt
# 04:38:13 - Не получили keywords данные 656594
# 04:38:14 - Не получили credits данные 656594
# 04:38:15 -  Не получили details данные 550493
# /tСохранен в error_requests.txt
# 04:38:16 - Не получили keywords данные 550493
# 04:38:17 - Не получили credits данные 550493
# 04:38:18 -  Не получили details данные 171338
# /tСохранен в error_requests.txt
# 04:38:20 - Не получили keywords данные 171338
# 04:38:21 - Не получили credits данные 171338
# 596      None
# 4092     None
# 4452     None
# 4952     None
# 7381     None
#          ...
# 64432    None
# 64433    None
# 64557    None
# 64713    None
# 64720    None
# Name: tmdbId, Length: 4869, dtype: object

# %%
error_tmdbId = []
with open('error_requests.txt', 'r') as f:
    for line in f.readlines():
        error_tmdbId.append(int(line.strip()))

# %%
movies.isna().sum()
# Out:
# tmdbId                       0
# adult                      980
# backdrop_path              980
# belongs_to_collection      980
# budget                     980
# genres                     980
# homepage                 10229
# id                         980
# imdb_id                    986
# original_language          980
# original_title             980
# overview                  1140
# popularity                 980
# poster_path                980
# production_companies       980
# production_countries       980
# release_date              1005
# revenue                    980
# runtime                    980
# spoken_languages           980
# status                     980
# tagline                   9548
# title                      980
# video                      980
# vote_average               980
# vote_count                 980
# dtype: int64

# %% [markdown]
# Не получилось собрать 980 записей. Удалим их из датасетов

# %%
tmdbId_empty_records = movies.loc[movies.adult.isna(), 'tmdbId'].tolist()

# %%
empty_records_index = movies.loc[movies.adult.isna()].index

# %%
movies = movies.drop(empty_records_index)
movies.drop_duplicates(inplace=True)

# %%
keywords = keywords.loc[keywords.tmdbId.isin(movies.tmdbId.tolist())].drop_duplicates()

# %%
credits = credits.loc[credits.tmdbId.isin(movies.tmdbId.tolist())].drop_duplicates()

# %%
movies.shape, keywords.shape, credits.shape
# Out:
# ((85463, 26), (85463, 2), (85469, 3))

# %% [markdown]
# У credits есть лишние 6 записей, которые говорят о том, что существуют дублирующие индификаторы с разной информацией. Найдем их и вывидем на экран

# %%
tmdbId_with_two_records = [159849, 132641, 110428, 4912, 298721, 99080]
credits.loc[credits.tmdbId.isin(tmdbId_with_two_records)]
# Out:
#        tmdbId                                               cast  \
# 844    132641  [{'cast_id': 4, 'character': 'Mihoko Nakagawa'...
# 845    132641  [{'cast_id': 4, 'character': 'Mihoko Nakagawa'...
# 5887     4912  [{'cast_id': 15, 'character': 'Chuck Barris', ...
# 5888     4912  [{'cast_id': 15, 'character': 'Chuck Barris', ...
# 21726  110428  [{'cast_id': 3, 'character': 'Camille Claudel'...
# 21727  110428  [{'cast_id': 3, 'character': 'Camille Claudel'...
# 33560  298721  [{'cast_id': 1, 'character': 'Jenjira', 'credi...
# 33561  298721  [{'cast_id': 1, 'character': 'Jenjira', 'credi...
# 36894  159849  [{'cast_id': 12, 'character': 'Narrator', 'cre...
# 36895  159849  [{'cast_id': 12, 'character': 'Narrator', 'cre...
# 40714   99080  [{'cast_id': 1004, 'character': 'Luke Oarum', ...
# 40715   99080  [{'cast_id': 1004, 'character': 'Luke Oarum', ...
#
#                                                     crew
# 844    [{'credit_id': '52fe4b9ac3a368484e190d25', 'de...
# 845    [{'credit_id': '56365ed9925141285701b06e', 'de...
# 5887   [{'credit_id': '52fe43e2c3a36847f80760b5', 'de...
# 5888   [{'credit_id': '52fe43e2c3a36847f80760a9', 'de...
# 21726  [{'credit_id': '52fe4ad6c3a36847f81e461b', 'de...
# 21727  [{'credit_id': '577ed5389251416976004432', 'de...
# 33560  [{'credit_id': '5448c8efc3a3680fb4001582', 'de...
# 33561  [{'credit_id': '5739ceeac3a3683c9d000c12', 'de...
# 36894  [{'credit_id': '52fe4c229251416c910f10d5', 'de...
# 36895  [{'credit_id': '52fe4c229251416c910f10d5', 'de...
# 40714  [{'credit_id': '52fe4a269251416c750df623', 'de...
# 40715  [{'credit_id': '52fe4a269251416c750df61d', 'de...

# %% [markdown]
# Так как не понятно, какая из строчек является истинной, то заново найдем значения для них.

# %%
credits = credits.drop([845, 5888, 21727, 33561, 36895, 40715])

# %%
for tmdbId in tmdbId_with_two_records:
    url = f"https://api.themoviedb.org/3/movie/{tmdbId}/credits?api_key={api_key}&language=en-US"
    headers = {
                "accept": "application/json",
                "Authorization": token
                }
    response = requests.get(url, headers=headers)
    if not response.ok:
        print(f'{ datetime.datetime.now().strftime("%H:%M:%S")} - Не получили credits данные {tmdbId}')
    else:
        credits_set = dict(response.json())
        for c_key in credits_keys:
            if c_key in credits_set.keys():
                credits.loc[credits.tmdbId == tmdbId, c_key] = str(credits_set[c_key])
        print(tmdbId)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\urllib3\connectionpool.py:700, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     699 if is_new_proxy_conn and http_tunnel_required:
# --> 700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
#
# File D:\Anaconda\lib\site-packages\urllib3\connectionpool.py:996, in HTTPSConnectionPool._prepare_proxy(self, conn)
#     994     conn.tls_in_tls_required = True
# --> 996 conn.connect()
#
# File D:\Anaconda\lib\site-packages\urllib3\connection.py:369, in HTTPSConnection.connect(self)
#     367 # Calls self._set_hostport(), so self.host is
#     368 # self._tunnel_host below.
# --> 369 self._tunnel()
#     370 # Mark this connection as not reusable
#
# File D:\Anaconda\lib\http\client.py:924, in HTTPConnection._tunnel(self)
#     923     self.close()
# --> 924     raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
#     925 while True:
#
# OSError: Tunnel connection failed: 403 Forbidden
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File D:\Anaconda\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File D:\Anaconda\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/159849/credits?api_key=c4cb6ffa32ab677f475d001b4cbd14a7&language=en-US (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# Cell In[309], line 7
#       2 url = f"https://api.themoviedb.org/3/movie/{tmdbId}/credits?api_key={api_key}&language=en-US"
#       3 headers = {
#       4             "accept": "application/json",
#       5             "Authorization": token
#       6             }
# ----> 7 response = requests.get(url, headers=headers)
#       8 if not response.ok:
#       9     print(f'{ datetime.datetime.now().strftime("%H:%M:%S")} - Не получили credits данные {tmdbId}')
#
# File D:\Anaconda\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File D:\Anaconda\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File D:\Anaconda\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File D:\Anaconda\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File D:\Anaconda\lib\site-packages\requests\adapters.py:559, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     556     raise RetryError(e, request=request)
#     558 if isinstance(e.reason, _ProxyError):
# --> 559     raise ProxyError(e, request=request)
#     561 if isinstance(e.reason, _SSLError):
#     562     # This branch is for urllib3 v1.22 and later.
#     563     raise SSLError(e, request=request)
#
# ProxyError: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/159849/credits?api_key=c4cb6ffa32ab677f475d001b4cbd14a7&language=en-US (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 403 Forbidden')))

# %%
movies.shape, keywords.shape, credits.shape
# Out:
# ((85463, 26), (85463, 2), (85463, 3))

# %% [markdown]
# Наши файлы готовы. Всего в датасете собрана информация о 85463 фильмов. Сохраняем конечный результат

# %%
movies.to_csv('full_data/movie_metadata_final.csv', index=False)
keywords.to_csv('full_data/keywords_final.csv', index=False)
credits.to_csv('full_data/credits_final.csv', index=False)
